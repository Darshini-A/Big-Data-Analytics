# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshini-A/Big-Data-Analytics/blob/main/Time_Series%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/TimeSeries - AirPassengers.csv')
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.columns = ['Date','Number of Passengers']
df.head()
# Out:
#       Date  Number of Passengers
# 0  1949-01                   112
# 1  1949-02                   118
# 2  1949-03                   132
# 3  1949-04                   129
# 4  1949-05                   121

# %%
df.plot()
plt.show()

# %%
from dateutil.parser import parse
from statsmodels.tsa.seasonal import seasonal_decompose

# Additive Decomposition
additive_decomposition = seasonal_decompose(df['Number of Passengers'], model = 'additive', period = 30)

# Multiplicative Decomposition
multiplicative_decomposition = seasonal_decompose(df['Number of Passengers'], model = 'multiplicative', period = 30)


plt.rcParams.update({'figure.figsize':(14,12)})

additive_decomposition.plot().suptitle('Additive Decomposition', fontsize = 26)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize = 26)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()

# %%
from pandas.plotting import lag_plot
plt.rcParams.update({'ytick.left':False, 'axes.titlepad':10})


fig, axes = plt.subplots(1, 4, figsize=(10,3), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate (axes.flatten ()[:4]):
  lag_plot(df[ 'Number of Passengers'], lag=i+1, ax=ax, c='firebrick')
  ax.set_title('Lag' + str(i+1))

fig.suptitle('Lag Plots of Air Passengers', y=1.1)
plt.show()
